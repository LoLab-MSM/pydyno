# %%
from tropical.examples.EARM.earm2_flat import model
import numpy
from tropical.cytoscapejs_visualization.model_visualization import ModelVisualization
from tropical.cytoscapejs_visualization.util_networkx import from_networkx

t = numpy.linspace(0, 20000, 100)
a = ModelVisualization(model)
data = a.dynamic_view(tspan=t, get_passengers=True)
# Out:
# /Users/dionisio/anaconda/envs/tropical_multi/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from tropical.cytoscapejs_visualization.cytoscapejs import viewer as cyjs
from IPython.display import display
q=cyjs.render(data, layout_algorithm='dagre')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#         body {
#             font: 14px helvetica neue, helvetica, arial, sans-serif;
#         }
#
#         ul li {
#             background: #ffe5e5;
#             padding: 5px;
#         }
#
#         .tooltiptext{
#             display: none;
#         }
#
#         .input-color {
#             position: relative;
#         }
#         .input-color input {
#             padding-left: 20px;
#         }
#         .input-color .color-box {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#             background-color: #ccc;
#             position: absolute;
#             left: 5px;
#             top: 8px;
#         }
#
#         #cy90275c56-ccb1-437c-ade8-b7fbc3694d07 {
#             height: 700px;
#             width: 100%;
#             position: absolute;
#             left: 4px;
#             top: 5px;
#             background: #FFFFFF;
#         }
#         #play0e56de75-53b2-4602-8176-4ed8dd5a6b5e {
#             width: 5%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 10%;
#         }
#
#         #reset20052eeb-f3ce-47c0-a2a0-673fbad5d669 {
#             width: 7%;
#             height: 4%;
#             font-size:130%;
#             position: absolute;
#             top: 93%;
#             left: 16%;
#         }
#
#         #range64b22c45-736f-419c-8192-abb501ffd2b4 {
#             width:80%;
#             height:25px;
#             top:89%;
#             left:10%;
#             border:1px solid black;
#             position:absolute;
#         }
#
#         #textd9b3b5ab-0532-4bb9-963d-dfa773a5b9f6 {
#             width:10%;
#             height:5%;
#             top:92.5%;
#             left:24%;
#             font-size:120%;
#             border:0px solid black;
#             position:absolute;
#         }
#         #fit682b6cf5-4205-4b36-abcf-4167e682688f {
#             width: 3em;
#             margin: 0.5em;
#             position: absolute;
#             z-index: 999;
#             top: 0;
#             right: 0;
#         }
#
#         #fit682b6cf5-4205-4b36-abcf-4167e682688f i {
#             transform: rotate(45deg);
#         }
#
#     </style>
#
#     <script>
#         (function() {
#             var all_data ={"elements": {"nodes": [{"position": {"y": 862.0, "x": 27.0}, "data": {"rel_value": [100.0, 98.70348090901587, 97.88023493781367, 97.35491292067854, 97.01839268368963, 96.80203435135331, 96.66236293245797, 96.57171958715685, 96.51245727646888, 96.47329596101783, 96.44701682495923, 96.42899653504048, 96.41627257172718, 96.406946005457, 96.3997993898421, 96.39405208021209, 96.38920346624666, 96.38493249514795, 96.38103325775744, 96.37737368773367, 96.37386907701492, 96.37046509165943, 96.36712687924862, 96.36383208285639, 96.36056636037644, 96.35732051063589, 96.35408863006406, 96.35086693034371, 96.34765298001064, 96.34444521799853, 96.34124264157046, 96.33804460616949, 96.33485069700572, 96.33166064669203, 96.32847428240323, 96.32529149198234, 96.32211220219435, 96.31893636477609, 96.31576394748654, 96.31259492836547, 96.30942929205013, 96.30626702741179, 96.30310812603972, 96.29995258126843, 96.29